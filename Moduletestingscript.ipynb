# %%
import pandas as pd
import numpy as np
import os
from  mda_core.time import Time

# %%
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
# %matplotlib inline

# %%
try:
    datafilepath = f'./Table3_Obs6.csv'

except:
    raise FileExistsError("File not found")

# %%
gpsselector = pd.DataFrame()

# %%
gpsselector = pd.read_csv(datafilepath)
gpsselector
# Out:
#        Index        Time  (OD_Y).s_ODSource_calc  \
# 0          0    0.000000                       3
# 1          1    0.009822                       3
# 2          2    0.020071                       3
# 3          3    0.029798                       3
# 4          4    0.040047                       3
# ...      ...         ...                     ...
# 19077  19077  190.770071                       3
# 19078  19078  190.779905                       3
# 19079  19079  190.789848                       3
# 19080  19080  190.799775                       3
# 19081  19081  190.809858                       3
#
#        (gps_vendor_dp_U).bool_disableGPSMain  \
# 0                                          1
# 1                                          1
# 2                                          1
# 3                                          1
# 4                                          1
# ...                                      ...
# 19077                                      1
# ...

# %%
gpssource = gpsselector.iloc[::100]
gpssource.columns
# Out:
# Index(['Index', 'Time', '(OD_Y).s_ODSource_calc',
#        '(gps_vendor_dp_U).bool_disableGPSMain',
#        '(gps_vendor_dp_U).bool_disableGPSRedundant', 'tm_mode',
#        '(OD_U).bool_useOnlySGP4', '(OD_U).bool_disableEKF'],
#       dtype='object')

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=gpsselector['Time'],y=gpsselector['(OD_Y).s_ODSource_calc']))
# fig.add_trace(go.Scatter(x=gpsselector['Time'],y=gpsselector['(OD_U).bool_disableEKF']))
plot_font = dict(family="Courier New, monospace", size=18, color="RebeccaPurple")
fig.update_layout(
font_family="Courier New",
font_color="black",
title_font_family="Times New Roman",
title_font_color="red",
legend_title_font_color="green",
title = 'OD Source'
)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=gpsselector['Time'],y=gpsselector['(gps_vendor_dp_U).bool_disableGPSMain']))
# fig.add_trace(go.Scatter(x=gpsselector['Time'],y=gpsselector['(OD_U).bool_disableEKF']))
plot_font = dict(family="Courier New, monospace", size=18, color="RebeccaPurple")
fig.update_layout(
font_family="Courier New",
font_color="black",
title_font_family="Times New Roman",
title_font_color="red",
legend_title_font_color="green",
title = 'Disable GPS Main'
)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=gpsselector['Time'],y=gpsselector['(OD_U).bool_useOnlySGP4']))
# fig.add_trace(go.Scatter(x=gpsselector['Time'],y=gpsselector['(OD_U).bool_disableEKF']))
plot_font = dict(family="Courier New, monospace", size=18, color="RebeccaPurple")
fig.update_layout(
font_family="Courier New",
font_color="black",
title_font_family="Times New Roman",
title_font_color="red",
legend_title_font_color="green",
title = 'Use only SGP4'
)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=gpsselector['Time'],y=gpsselector['(OD_U).bool_disableEKF']))
# fig.add_trace(go.Scatter(x=gpsselector['Time'],y=gpsselector['(OD_U).bool_disableEKF']))
plot_font = dict(family="Courier New, monospace", size=18, color="RebeccaPurple")
fig.update_layout(
font_family="Courier New",
font_color="black",
title_font_family="Times New Roman",
title_font_color="red",
legend_title_font_color="green",
title = 'Disable EKF'
)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=gpsselector['Time'],y=gpsselector['(gps_vendor_dp_U).bool_disableGPSRedundant']))
# fig.add_trace(go.Scatter(x=gpsselector['Time'],y=gpsselector['(OD_U).bool_disableEKF']))
plot_font = dict(family="Courier New, monospace", size=18, color="RebeccaPurple")
fig.update_layout(
font_family="Courier New",
font_color="black",
title_font_family="Times New Roman",
title_font_color="red",
legend_title_font_color="green",
title = 'Disable GPS Redundant'
)
